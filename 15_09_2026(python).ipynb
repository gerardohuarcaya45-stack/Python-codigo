# %% [markdown]
# <a href="https://colab.research.google.com/github/gerardohuarcaya45-stack/Python-codigo/blob/main/15_09_2026(python).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""
Ejercicio 1:

Elabore un programa, el cual se permite el ingreso
de 5 sueldos.
"""
print("Formato A: for simple")
for i in range(5): # i => 0, 1, 2, 3, 4
    print("Sueldo Nº: ", i+1)
    sueldo = float(input("ingrese Sueldo: "))

print()

print("Formato B: for Personalizado")
for i in range(1, 6, 1): # i => 1, 2, 3, 4, 5
    print("Sueldo Nº: ", i)
    sueldo = float(input("ingrese Sueldo: "))
# Out:
# Formato A: for simple
# Sueldo Nº:  1
# ingrese Sueldo: 5
# Sueldo Nº:  2
# ingrese Sueldo: 5
# Sueldo Nº:  3
# ingrese Sueldo: 5
# Sueldo Nº:  4
# ingrese Sueldo:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_3596/3347318115.py in <cell line: 0>()
#       8 for i in range(5): # i => 0, 1, 2, 3, 4
#       9     print("Sueldo Nº: ", i+1)
# ---> 10     sueldo = float(input("ingrese Sueldo: "))
#      11
#      12 print()
#
# ValueError: could not convert string to float: ''
